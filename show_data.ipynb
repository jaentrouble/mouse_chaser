# %%
import pickle
import matplotlib.pyplot as plt
from skimage import draw

# %%
# %matplotlib inline

# %%
with open('records/divided/4cham_0/save/6.pck','rb') as f:
    datum = pickle.load(f)

# %%
image = datum[0]['image']
image = image.swapaxes(0,1)
xx, yy = draw.disk(datum[0]['head'][::-1],5)
image[xx,yy] = [255,255,0]
plt.imshow(image)
